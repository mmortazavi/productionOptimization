# %% [markdown]
# https://modal-python.readthedocs.io/en/latest/content/examples/bayesian_optimization.html

# %%
import numpy as np
import matplotlib.pyplot as plt
from functools import partial
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern
from modAL.models import BayesianOptimizer
from modAL.acquisition import optimizer_EI, max_EI

# %matplotlib inline

# %% [markdown]
# ### Define an objective function¶

# %%
noise = 0.2
bounds = np.array([[-1.0, 2.0]], dtype=np.double)

def f(X, noise=noise):
    return -np.sin(3*X) - X**2 + 0.7*X + noise * np.random.randn(*X.shape)

# Dense grid of points within bounds
X = np.arange(bounds[:, 0], bounds[:, 1], 0.01).reshape(-1, 1)

# Noise-free objective function values at X 
y = f(X,0)

# %% [markdown]
# ## Data

# %%
with plt.style.context('seaborn-white'):
    plt.figure(figsize=(10, 5))
    plt.plot(X, y, c='k', linewidth=6)
    plt.title('The function to be optimized')
    plt.show()

# %% [markdown]
# ### Gaussian processes

# %%
# assembling initial training set
X_initial, y_initial = X[10].reshape(1, -1), y[10].reshape(1, -1)

# defining the kernel for the Gaussian process
kernel = Matern(length_scale=1.0)
regressor = MyGPR(kernel=kernel)

# %% [markdown]
# ### Optimizing using expected improvement

# %%
# initializing the optimizer
optimizer = BayesianOptimizer(
    estimator=regressor,
    X_training=X_initial, y_training=y_initial,
    query_strategy=max_EI)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOptBaysianmodAL.ipynb Cell 10' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000012?line=0'>1</a> # initializing the optimizer
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000012?line=1'>2</a> optimizer = BayesianOptimizer(
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000012?line=2'>3</a>     estimator=regressor,
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000012?line=3'>4</a>     X_training=X_initial, y_training=y_initial,
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000012?line=4'>5</a>     query_strategy=max_EI
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000012?line=5'>6</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000012?line=6'>7</a> )
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\modAL\models\learners.py:185, in BayesianOptimizer.__init__(self, estimator, query_strategy, X_training, y_training, bootstrap_init, on_transformed, **fit_kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=176'>177</a> def __init__(self,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=177'>178</a>              estimator: BaseEstimator,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=178'>179</a>              query_strategy: Callable = max_EI,
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=182'>183</a>              on_transformed: bool = False,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=183'>184</a>              **fit_kwargs) -> None:
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=184'>185</a>     super(BayesianOptimizer, self).__init__(estimator, query_strategy,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=185'>186</a>                                             X_training, y_training, bootstrap_init, on_transformed, **fit_kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=186'>187</a>     # setting the maximum value
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/learners.py?line=187'>188</a>     if self.y_training is not None:
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\modAL\models\base.py:71, in BaseLearner.__init__(self, estimator, query_strategy, X_training, y_training, bootstrap_init, on_transformed, force_all_finite, **fit_kwargs)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=68'>69</a> self.y_training = y_training
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=69'>70</a> if X_training is not None:
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=70'>71</a>     self._fit_to_known(bootstrap=bootstrap_init, **fit_kwargs)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=72'>73</a> assert isinstance(force_all_finite, bool), 'force_all_finite must be a bool'
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=73'>74</a> self.force_all_finite = force_all_finite
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\modAL\models\base.py:155, in BaseLearner._fit_to_known(self, bootstrap, **fit_kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=143'>144</a> """
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=144'>145</a> Fits self.estimator to the training data and labels provided to it so far.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=145'>146</a>
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=151'>152</a>     self
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=152'>153</a> """
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=153'>154</a> if not bootstrap:
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=154'>155</a>     self.estimator.fit(self.X_training, self.y_training, **fit_kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=155'>156</a> else:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/modAL/models/base.py?line=156'>157</a>     n_instances = self.X_training.shape[0]
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:272, in GaussianProcessRegressor.fit(self, X, y)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=266'>267</a>         return -self.log_marginal_likelihood(theta, clone_kernel=False)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=268'>269</a> # First optimize starting from theta specified in kernel
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=269'>270</a> optima = [
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=270'>271</a>     (
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=271'>272</a>         self._constrained_optimization(
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=272'>273</a>             obj_func, self.kernel_.theta, self.kernel_.bounds
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=273'>274</a>         )
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=274'>275</a>     )
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=275'>276</a> ]
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=277'>278</a> # Additional runs are performed from log-uniform chosen initial
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=278'>279</a> # theta
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=279'>280</a> if self.n_restarts_optimizer > 0:
#
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOptBaysianmodAL.ipynb Cell 2' in MyGPR._constrained_optimization(self, obj_func, initial_theta, bounds)
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=11'>12</a>     return scipy.optimize.minimize(
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=12'>13</a>         obj_func,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=13'>14</a>         initial_theta,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=17'>18</a>         max_iter=self._max_iter,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=18'>19</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=19'>20</a> self.optimizer = new_optimizer
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=20'>21</a> return super()._constrained_optimization(obj_func, initial_theta, bounds)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:613, in GaussianProcessRegressor._constrained_optimization(self, obj_func, initial_theta, bounds)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=610'>611</a>     theta_opt, func_min = opt_res.x, opt_res.fun
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=611'>612</a> elif callable(self.optimizer):
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=612'>613</a>     theta_opt, func_min = self.optimizer(obj_func, initial_theta, bounds=bounds)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=613'>614</a> else:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/sklearn/gaussian_process/_gpr.py?line=614'>615</a>     raise ValueError(f"Unknown optimizer {self.optimizer}.")
#
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOptBaysianmodAL.ipynb Cell 2' in MyGPR._constrained_optimization.<locals>.new_optimizer(obj_func, initial_theta, bounds)
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=10'>11</a> def new_optimizer(obj_func, initial_theta, bounds):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=11'>12</a>     return scipy.optimize.minimize(
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=12'>13</a>         obj_func,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=13'>14</a>         initial_theta,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=14'>15</a>         method="L-BFGS-B",
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=15'>16</a>         jac=True,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=16'>17</a>         bounds=bounds,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=17'>18</a>         max_iter=self._max_iter,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOptBaysianmodAL.ipynb#ch0000027?line=18'>19</a>     )
#
# TypeError: minimize() got an unexpected keyword argument 'max_iter'

# %%
# Bayesian optimization
for n_query in range(30):
    query_idx, query_inst = optimizer.query(X)
    optimizer.teach(X[query_idx].reshape(1, -1), y[query_idx].reshape(1, -1))
# Out:
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)

# %%
y_pred, y_std = optimizer.predict(X, return_std=True)
y_pred, y_std = y_pred.ravel(), y_std.ravel()
X_max, y_max = optimizer.get_max()

# %% [markdown]
# ### Define an acquisition function¶

# %%
with plt.style.context('seaborn-white'):
    plt.figure(figsize=(10, 5))
    plt.scatter(optimizer.X_training, optimizer.y_training, c='k', s=50, label='Queried')
    plt.scatter(X_max, y_max, s=100, c='r', label='Current optimum')
    plt.plot(X.ravel(), y, c='k', linewidth=2, label='Function')
    plt.plot(X.ravel(), y_pred, label='GP regressor')
    plt.fill_between(X.ravel(), y_pred - y_std, y_pred + y_std, alpha=0.5)
    plt.title('First five queries of Bayesian optimization')
    plt.legend()
    plt.show()
