# %%
import torch
import numpy as np
import pandas as pd


import matplotlib.pyplot as plt

from botorch.models import SingleTaskGP, ModelListGP, MultiTaskGP
from gpytorch.mlls.exact_marginal_log_likelihood import ExactMarginalLogLikelihood
from gpytorch.constraints import GreaterThan
from botorch import fit_gpytorch_model

from botorch import acquisition
from botorch.acquisition.monte_carlo import qExpectedImprovement
from botorch.optim import optimize_acqf

import os

import matplotlib.pyplot as plt
import numpy as np
import torch
from botorch import fit_fully_bayesian_model_nuts
from botorch.acquisition import qExpectedImprovement
from botorch.models.fully_bayesian import SaasFullyBayesianSingleTaskGP
from botorch.models.transforms import Standardize
from botorch.optim import optimize_acqf
from botorch.test_functions import Branin
from torch.quasirandom import SobolEngine


from sklearn.model_selection import train_test_split

# %matplotlib inline
SMOKE_TEST = os.environ.get("SMOKE_TEST")

# %%
tkwargs = {"device": torch.device("cuda" if torch.cuda.is_available() else "cpu"), "dtype": torch.double}

# %% [markdown]
# ### Objective Function & Data

# %%
from mpl_toolkits.mplot3d import Axes3D


def generate_3d_data(xmin, xmax, ymin, ymax, line_mesh):

    # The two-dimensional domain of the fit.
    xmin, xmax, nx = xmin, xmax, line_mesh
    ymin, ymax, ny = ymin, ymax, line_mesh
    x, y = np.linspace(xmin, xmax, nx), np.linspace(ymin, ymax, ny)
    X, Y = np.meshgrid(x, y)

    # Our function to fit is going to be a sum of two-dimensional Gaussians
    def gaussian(x, y, x0, y0, xalpha, yalpha, A):
        return A * np.exp( -((x-x0)/xalpha)**2 -((y-y0)/yalpha)**2)

    # A list of the Gaussian parameters: x0, y0, xalpha, yalpha, A
    gprms = [(0, 2, 2.5, 5.4, 1.5),
            (-1, 4, 6, 2.5, 1.8),
            (-3, -0.5, 1, 2, 4),
            (3, 0.5, 2, 1, 5)
            ]

    # Standard deviation of normally-distributed noise to add in generating
    # our test function to fit.
    noise_sigma = 0.1

    # The function to be fit is Z.
    Z = np.zeros(X.shape)
    for p in gprms:
        Z += gaussian(X, Y, *p)
    Z += noise_sigma * np.random.randn(*Z.shape)

    return X, Y, Z

X, Y, Z = generate_3d_data(-5, 4, -3, 7, 100)
# Plot the 3D figure of the fitted function and the residuals.
fig = plt.figure(figsize=(10, 10))
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma')
ax.set_zlim(0,np.max(Z))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface')
plt.show();
# Out:
# C:\Users\MajidMortazavi\AppData\Local\Temp\ipykernel_9004\4072858525.py:38: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
xmin, xmax, ymin, ymax = -5, 4, -3, 7
X, Y, Y = generate_3d_data(xmin, xmax, ymin, ymax, 100)
df = pd.DataFrame(columns=['X','Y','Z'], dtype=float)

df['X'] = X.reshape(-1, ).astype(float)
df['Y'] = Y.reshape(-1, ).astype(float)
df['Z'] = Z.reshape(-1, ).astype(float)


train_X , test_X, train_Y, test_Y  = train_test_split(df[['X', "Y"]].values, df[['Z']].values, test_size=0.2)

train_X = torch.tensor(train_X)
test_X = torch.tensor(test_X)
train_Y = torch.tensor(train_Y)
test_Y = torch.tensor(test_Y)

# %% [markdown]
# ### High-Dimensional sample-efficient Bayesian Optimization

# %%
WARMUP_STEPS = 512 if not SMOKE_TEST else 32
NUM_SAMPLES = 256 if not SMOKE_TEST else 16
THINNING = 16

# %%
gp = SaasFullyBayesianSingleTaskGP(train_X=train_X, train_Y=train_Y)
fit_fully_bayesian_model_nuts(
    gp, warmup_steps=WARMUP_STEPS, num_samples=NUM_SAMPLES, thinning=THINNING, disable_progbar=True
)
# Out:
# c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\pyro\infer\mcmc\adaptation.py:235: UserWarning: torch.triangular_solve is deprecated in favor of torch.linalg.solve_triangularand will be removed in a future PyTorch release.
# torch.linalg.solve_triangular has its arguments reversed and does not return a copy of one of the inputs.
# X = torch.triangular_solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve_triangular(A, B). (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\BatchLinearAlgebra.cpp:1672.)
#   return torch.triangular_solve(identity, x, upper=True)[0]

# %%
with torch.no_grad():
    posterior = gp.posterior(test_X)

# %% [markdown]
# ### Make predictions with the model

# %%
print(f"Ground truth:     {test_Y.squeeze(-1)}")
print(f"Mixture mean:     {posterior.mixture_mean.squeeze(-1)}")
print(f"Mixture median:   {posterior.mixture_median.squeeze(-1)}")

# %% [markdown]
# ### Optimize  Explore Next Test Point

# %%
init_x = torch.tensor(x)
init_y = torch.tensor(y).unsqueeze(-1)

model = SingleTaskGP(init_x, init_y)
mll = ExactMarginalLogLikelihood(likelihood=model.likelihood, model=model)
fit_gpytorch_model(mll)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOpt3D_BO-BoTorch.ipynb Cell 6' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000005?line=3'>4</a> model = SingleTaskGP(init_x, init_y)
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000005?line=4'>5</a> mll = ExactMarginalLogLikelihood(likelihood=model.likelihood, model=model)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000005?line=5'>6</a> fit_gpytorch_model(mll)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\fit.py:125, in fit_gpytorch_model(mll, optimizer, **kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/fit.py?line=122'>123</a>     sample_all_priors(mll.model)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/fit.py?line=123'>124</a> try:
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/fit.py?line=124'>125</a>     mll, _ = optimizer(mll, track_iterations=False, **kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/fit.py?line=125'>126</a> except NotPSDError:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/fit.py?line=126'>127</a>     retry += 1
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\optim\fit.py:239, in fit_gpytorch_scipy(mll, bounds, method, options, track_iterations, approx_mll, scipy_objective, module_to_array_func, module_from_array_func)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=235'>236</a> cb = store_iteration if track_iterations else None
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=237'>238</a> with gpt_settings.fast_computations(log_prob=approx_mll):
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=238'>239</a>     res = minimize(
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=239'>240</a>         scipy_objective,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=240'>241</a>         x0,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=241'>242</a>         args=(mll, property_dict),
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=242'>243</a>         bounds=bounds,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=243'>244</a>         method=method,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=244'>245</a>         jac=True,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=245'>246</a>         options=options,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=246'>247</a>         callback=cb,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=247'>248</a>     )
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=248'>249</a>     iterations = []
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/fit.py?line=249'>250</a>     if track_iterations:
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\_minimize.py:623, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=619'>620</a>     return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=620'>621</a>                               **options)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=621'>622</a> elif meth == 'l-bfgs-b':
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=622'>623</a>     return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=623'>624</a>                             callback=callback, **options)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=624'>625</a> elif meth == 'tnc':
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=625'>626</a>     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_minimize.py?line=626'>627</a>                          **options)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\lbfgsb.py:360, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=353'>354</a> task_str = task.tobytes()
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=354'>355</a> if task_str.startswith(b'FG'):
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=355'>356</a>     # The minimization routine wants f and g at the current x.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=356'>357</a>     # Note that interruptions due to maxfun are postponed
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=357'>358</a>     # until the completion of the current minimization iteration.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=358'>359</a>     # Overwrite f and g:
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=359'>360</a>     f, g = func_and_grad(x)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=360'>361</a> elif task_str.startswith(b'NEW_X'):
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=361'>362</a>     # new iteration
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/lbfgsb.py?line=362'>363</a>     n_iterations += 1
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction.fun_and_grad(self, x)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=264'>265</a> if not np.array_equal(x, self.x):
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=265'>266</a>     self._update_x_impl(x)
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=266'>267</a> self._update_fun()
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=267'>268</a> self._update_grad()
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=268'>269</a> return self.f, self.g
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=230'>231</a> def _update_fun(self):
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=231'>232</a>     if not self.f_updated:
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=232'>233</a>         self._update_fun_impl()
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=233'>234</a>         self.f_updated = True
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=135'>136</a> def update_fun():
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=136'>137</a>     self.f = fun_wrapped(self.x)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=129'>130</a> self.nfev += 1
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=130'>131</a> # Send a copy because the user may overwrite it.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=131'>132</a> # Overwriting results in undefined behaviour because
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=132'>133</a> # fun(self.x) will change self.x, with the two no longer linked.
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/_differentiable_functions.py?line=133'>134</a> return fun(np.copy(x), *args)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\optimize.py:74, in MemoizeJac.__call__(self, x, *args)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=71'>72</a> def __call__(self, x, *args):
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=72'>73</a>     """ returns the the function value """
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=73'>74</a>     self._compute_if_needed(x, *args)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=74'>75</a>     return self._value
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\scipy\optimize\optimize.py:68, in MemoizeJac._compute_if_needed(self, x, *args)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=65'>66</a> if not np.all(x == self.x) or self._value is None or self.jac is None:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=66'>67</a>     self.x = np.asarray(x).copy()
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=67'>68</a>     fg = self.fun(x, *args)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=68'>69</a>     self.jac = fg[1]
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/scipy/optimize/optimize.py?line=69'>70</a>     self._value = fg[0]
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\optim\utils.py:215, in _scipy_objective_and_grad(x, mll, property_dict)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/utils.py?line=212'>213</a>     output = mll.model(*train_inputs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/utils.py?line=213'>214</a>     args = [output, train_targets] + _get_extra_mll_args(mll)
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/utils.py?line=214'>215</a>     loss = -mll(*args).sum()
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/utils.py?line=215'>216</a> except RuntimeError as e:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/optim/utils.py?line=216'>217</a>     return _handle_numerical_errors(error=e, x=x)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\module.py:30, in Module.__call__(self, *inputs, **kwargs)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/module.py?line=28'>29</a> def __call__(self, *inputs, **kwargs):
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/module.py?line=29'>30</a>     outputs = self.forward(*inputs, **kwargs)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/module.py?line=30'>31</a>     if isinstance(outputs, list):
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/module.py?line=31'>32</a>         return [_validate_module_outputs(output) for output in outputs]
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\mlls\exact_marginal_log_likelihood.py:62, in ExactMarginalLogLikelihood.forward(self, function_dist, target, *params)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/mlls/exact_marginal_log_likelihood.py?line=59'>60</a> # Get the log prob of the marginal distribution
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/mlls/exact_marginal_log_likelihood.py?line=60'>61</a> output = self.likelihood(function_dist, *params)
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/mlls/exact_marginal_log_likelihood.py?line=61'>62</a> res = output.log_prob(target)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/mlls/exact_marginal_log_likelihood.py?line=62'>63</a> res = self._add_other_terms(res, params)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/mlls/exact_marginal_log_likelihood.py?line=64'>65</a> # Scale by the amount of data we have
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\distributions\multivariate_normal.py:147, in MultivariateNormal.log_prob(self, value)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=144'>145</a> def log_prob(self, value):
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=145'>146</a>     if settings.fast_computations.log_prob.off():
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=146'>147</a>         return super().log_prob(value)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=148'>149</a>     if self._validate_args:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=149'>150</a>         self._validate_sample(value)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\torch\distributions\multivariate_normal.py:208, in MultivariateNormal.log_prob(self, value)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/torch/distributions/multivariate_normal.py?line=205'>206</a>     self._validate_sample(value)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/torch/distributions/multivariate_normal.py?line=206'>207</a> diff = value - self.loc
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/torch/distributions/multivariate_normal.py?line=207'>208</a> M = _batch_mahalanobis(self._unbroadcasted_scale_tril, diff)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/torch/distributions/multivariate_normal.py?line=208'>209</a> half_log_det = self._unbroadcasted_scale_tril.diagonal(dim1=-2, dim2=-1).log().sum(-1)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/torch/distributions/multivariate_normal.py?line=209'>210</a> return -0.5 * (self._event_shape[0] * math.log(2 * math.pi) + M) - half_log_det
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\distributions\multivariate_normal.py:57, in MultivariateNormal._unbroadcasted_scale_tril(self)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=52'>53</a> @property
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=53'>54</a> def _unbroadcasted_scale_tril(self):
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=54'>55</a>     if self.islazy and self.__unbroadcasted_scale_tril is None:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=55'>56</a>         # cache root decoposition
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=56'>57</a>         ust = delazify(self.lazy_covariance_matrix.cholesky())
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=57'>58</a>         self.__unbroadcasted_scale_tril = ust
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/distributions/multivariate_normal.py?line=58'>59</a>     return self.__unbroadcasted_scale_tril
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\lazy\lazy_tensor.py:1004, in LazyTensor.cholesky(self, upper)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=993'>994</a> def cholesky(self, upper=False):
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=994'>995</a>     """
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=995'>996</a>     Cholesky-factorizes the LazyTensor
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=996'>997</a>
#    (...)
#    <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=1001'>1002</a>         (LazyTensor) Cholesky factor (triangular, upper/lower depending on "upper" arg)
#    <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=1002'>1003</a>     """
# -> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=1003'>1004</a>     chol = self._cholesky(upper=False)
#    <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=1004'>1005</a>     if upper:
#    <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=1005'>1006</a>         chol = chol._transpose_nonbatch()
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\utils\memoize.py:59, in _cached.<locals>.g(self, *args, **kwargs)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/memoize.py?line=56'>57</a> kwargs_pkl = pickle.dumps(kwargs)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/memoize.py?line=57'>58</a> if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/memoize.py?line=58'>59</a>     return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/memoize.py?line=59'>60</a> return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\lazy\lazy_tensor.py:435, in LazyTensor._cholesky(self, upper)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=431'>432</a>     return TriangularLazyTensor(evaluated_mat.clamp_min(0.0).sqrt())
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=433'>434</a> # contiguous call is necessary here
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=434'>435</a> cholesky = psd_safe_cholesky(evaluated_mat, upper=upper).contiguous()
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/lazy/lazy_tensor.py?line=435'>436</a> return TriangularLazyTensor(cholesky, upper=upper)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\utils\cholesky.py:63, in psd_safe_cholesky(A, upper, out, jitter, max_tries)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=47'>48</a> def psd_safe_cholesky(A, upper=False, out=None, jitter=None, max_tries=3):
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=48'>49</a>     """Compute the Cholesky decomposition of A. If A is only p.s.d, add a small jitter to the diagonal.
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=49'>50</a>     Args:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=50'>51</a>         :attr:`A` (Tensor):
#    (...)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=60'>61</a>             Number of attempts (with successively increasing jitter) to make before raising an error.
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=61'>62</a>     """
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=62'>63</a>     L = _psd_safe_cholesky(A, out=out, jitter=jitter, max_tries=max_tries)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=63'>64</a>     if upper:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=64'>65</a>         if out is not None:
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\gpytorch\utils\cholesky.py:20, in _psd_safe_cholesky(A, out, jitter, max_tries)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=16'>17</a> if out is not None:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=17'>18</a>     out = (out, torch.empty(A.shape[:-2], dtype=torch.int32, device=out.device))
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=19'>20</a> L, info = torch.linalg.cholesky_ex(A, out=out)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=20'>21</a> if not torch.any(info):
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/gpytorch/utils/cholesky.py?line=21'>22</a>     return L
#
# KeyboardInterrupt:

# %%
EI = qExpectedImprovement(model=model, best_f= 0)

bounds = torch.tensor([[-5., -3.0], [4., 7.0]])

candidates, _ = optimize_acqf(acq_function=EI,
                                bounds=bounds,
                                q=1,
                                num_restarts=200,
                                raw_samples=512,
                                options={'batch_limit': 5, 'maxiter': 100})
# Out:
# ---------------------------------------------------------------------------
# UnsupportedError                          Traceback (most recent call last)
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOpt3D_BO-BoTorch.ipynb Cell 9' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=0'>1</a> EI = qExpectedImprovement(model=model, best_f= 0)
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=2'>3</a> bounds = torch.tensor([[-5., -3.0], [4., 7.0]])
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=4'>5</a> candidates, _ = optimize_acqf(acq_function=EI,
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=5'>6</a>                                 bounds=bounds,
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=6'>7</a>                                 q=1,
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=7'>8</a>                                 num_restarts=200,
#       <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=8'>9</a>                                 raw_samples=512,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000019?line=9'>10</a>                                 options={'batch_limit': 5, 'maxiter': 100})
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\acquisition\monte_carlo.py:151, in qExpectedImprovement.__init__(self, model, best_f, sampler, objective, posterior_transform, X_pending, **kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=123'>124</a> def __init__(
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=124'>125</a>     self,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=125'>126</a>     model: Model,
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=131'>132</a>     **kwargs: Any,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=132'>133</a> ) -> None:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=133'>134</a>     r"""q-Expected Improvement.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=134'>135</a>
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=135'>136</a>     Args:
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=148'>149</a>             gradient.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=149'>150</a>     """
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=150'>151</a>     super().__init__(
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=151'>152</a>         model=model,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=152'>153</a>         sampler=sampler,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=153'>154</a>         objective=objective,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=154'>155</a>         posterior_transform=posterior_transform,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=155'>156</a>         X_pending=X_pending,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=156'>157</a>     )
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=157'>158</a>     self.register_buffer("best_f", torch.as_tensor(best_f, dtype=float))
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\acquisition\monte_carlo.py:79, in MCAcquisitionFunction.__init__(self, model, sampler, objective, posterior_transform, X_pending)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=76'>77</a> if objective is None and model.num_outputs != 1:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=77'>78</a>     if posterior_transform is None:
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=78'>79</a>         raise UnsupportedError(
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=79'>80</a>             "Must specify an objective or a posterior transform when using "
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=80'>81</a>             "a multi-output model."
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=81'>82</a>         )
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=82'>83</a>     elif not posterior_transform.scalarize:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=83'>84</a>         raise UnsupportedError(
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=84'>85</a>             "If using a multi-output model without an objective, "
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=85'>86</a>             "posterior_transform must scalarize the output."
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=86'>87</a>         )
#
# UnsupportedError: Must specify an objective or a posterior transform when using a multi-output model.

# %%
    plt.plot(bo.max["params"]["X"],bo.max["params"]["Y"], '*', markersize=10)
    plt.show()
    
    utility = UtilityFunction(kind="ucb", kappa=kappa, xi=0)
    next_point_to_probe = bo.suggest(utility)


    print(f"Next Point to Probe: {next_point_to_probe}")
    print(f"Optimal Point: {bo.max}")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedError                          Traceback (most recent call last)
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOpt3D_BO-BoTorch.ipynb Cell 7' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000021?line=0'>1</a> EI = acquisition.UpperConfidenceBound(model=model, best_f= 0, beta=1)
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\acquisition\analytic.py:309, in UpperConfidenceBound.__init__(self, model, beta, posterior_transform, maximize, **kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=288'>289</a> def __init__(
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=289'>290</a>     self,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=290'>291</a>     model: Model,
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=294'>295</a>     **kwargs,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=295'>296</a> ) -> None:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=296'>297</a>     r"""Single-outcome Upper Confidence Bound.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=297'>298</a>
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=298'>299</a>     Args:
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=306'>307</a>         maximize: If True, consider the problem a maximization problem.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=307'>308</a>     """
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=308'>309</a>     super().__init__(model=model, posterior_transform=posterior_transform, **kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=309'>310</a>     self.maximize = maximize
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=310'>311</a>     if not torch.is_tensor(beta):
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\acquisition\analytic.py:55, in AnalyticAcquisitionFunction.__init__(self, model, posterior_transform, **kwargs)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=52'>53</a> if posterior_transform is None:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=53'>54</a>     if model.num_outputs != 1:
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=54'>55</a>         raise UnsupportedError(
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=55'>56</a>             "Must specify a posterior transform when using a "
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=56'>57</a>             "multi-output model."
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=57'>58</a>         )
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=58'>59</a> else:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/analytic.py?line=59'>60</a>     if not isinstance(posterior_transform, PosteriorTransform):
#
# UnsupportedError: Must specify a posterior transform when using a multi-output model.

# %%
bounds = torch.tensor([[-5., -3.0], [4., 7.0]])

candidates, _ = optimize_acqf(acq_function=EI,
                                bounds=bounds,
                                q=1,
                                num_restarts=200,
                                raw_samples=512,
                                options={'batch_limit': 5, 'maxiter': 100})

# %% [markdown]
# ### Next Experiment

# %%
def gen_next_point(X, Y, Z, best_init_y, bounds, n_points=1):
    
    """ 
    
    A Function to generate the next point to be evaluated.

    Args:
        init_x: The initial point
        init_y: The initial value of the function at the initial point
        best_init_y: The best value of the function seen so far
        bounds: The bounds of the function
        n_points: The number of points to generate

    Returns:
        candidate: Potential next candidate to be evaluated
    """
    init_x = torch.tensor([X, Y])
    init_y = torch.tensor([Z])

    model = SingleTaskGP(init_x, init_y)
    mll = ExactMarginalLogLikelihood(likelihood=model.likelihood, model=model)
    fit_gpytorch_model(mll)

    EI = qExpectedImprovement(model=model, best_f= best_init_y)

    candidates, _ = optimize_acqf(acq_function=EI,
                                    bounds=bounds,
                                    q=n_points,
                                    num_restarts=200,
                                    raw_samples=512,
                                    options={'batch_limit': 5, 'maxiter': 100})
    
    print(f"The next point to be evaluated is {candidates}")

    return candidates


bounds = torch.tensor([[-5., -3.0], [4., 7.0]])
gen_next_point(X1, X2, Y, 0, bounds)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedError                          Traceback (most recent call last)
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOpt3D_BO-BoTorch.ipynb Cell 7' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=34'>35</a>     return candidates
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=37'>38</a> bounds = torch.tensor([[-5., -3.0], [4., 7.0]])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=38'>39</a> gen_next_point(X1, X2, Y, 0, bounds)
#
# c:\Users\MajidMortazavi\Git\productionOptimization\prodOpt3D_BO-BoTorch.ipynb Cell 7' in gen_next_point(X1, X2, Y, best_init_y, bounds, n_points)
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=20'>21</a> mll = ExactMarginalLogLikelihood(likelihood=model.likelihood, model=model)
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=21'>22</a> fit_gpytorch_model(mll)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=23'>24</a> EI = qExpectedImprovement(model=model, best_f= best_init_y)
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=25'>26</a> candidates, _ = optimize_acqf(acq_function=EI,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=26'>27</a>                                 bounds=bounds,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=27'>28</a>                                 q=n_points,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=28'>29</a>                                 num_restarts=200,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=29'>30</a>                                 raw_samples=512,
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=30'>31</a>                                 options={'batch_limit': 5, 'maxiter': 100})
#      <a href='vscode-notebook-cell:/c%3A/Users/MajidMortazavi/Git/productionOptimization/prodOpt3D_BO-BoTorch.ipynb#ch0000006?line=32'>33</a> print(f"The next point to be evaluated is {candidates}")
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\acquisition\monte_carlo.py:151, in qExpectedImprovement.__init__(self, model, best_f, sampler, objective, posterior_transform, X_pending, **kwargs)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=123'>124</a> def __init__(
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=124'>125</a>     self,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=125'>126</a>     model: Model,
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=131'>132</a>     **kwargs: Any,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=132'>133</a> ) -> None:
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=133'>134</a>     r"""q-Expected Improvement.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=134'>135</a>
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=135'>136</a>     Args:
#    (...)
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=148'>149</a>             gradient.
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=149'>150</a>     """
# --> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=150'>151</a>     super().__init__(
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=151'>152</a>         model=model,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=152'>153</a>         sampler=sampler,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=153'>154</a>         objective=objective,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=154'>155</a>         posterior_transform=posterior_transform,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=155'>156</a>         X_pending=X_pending,
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=156'>157</a>     )
#     <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=157'>158</a>     self.register_buffer("best_f", torch.as_tensor(best_f, dtype=float))
#
# File c:\Users\MajidMortazavi\Git\productionOptimization\venv\lib\site-packages\botorch\acquisition\monte_carlo.py:79, in MCAcquisitionFunction.__init__(self, model, sampler, objective, posterior_transform, X_pending)
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=76'>77</a> if objective is None and model.num_outputs != 1:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=77'>78</a>     if posterior_transform is None:
# ---> <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=78'>79</a>         raise UnsupportedError(
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=79'>80</a>             "Must specify an objective or a posterior transform when using "
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=80'>81</a>             "a multi-output model."
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=81'>82</a>         )
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=82'>83</a>     elif not posterior_transform.scalarize:
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=83'>84</a>         raise UnsupportedError(
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=84'>85</a>             "If using a multi-output model without an objective, "
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=85'>86</a>             "posterior_transform must scalarize the output."
#      <a href='file:///c%3A/Users/MajidMortazavi/Git/productionOptimization/venv/lib/site-packages/botorch/acquisition/monte_carlo.py?line=86'>87</a>         )
#
# UnsupportedError: Must specify an objective or a posterior transform when using a multi-output model.

# %% [markdown]
# ### Gaussian processes & Optimizing using expected improvement

# %%
n_runs = 10

# Dense grid of points within bounds
init_x, init_y, best_observed_y = generate_initial_data(-2, 3, 10, 0)
bounds = torch.tensor([[-2.], [3.]])

for i in range(n_runs):
    print(f"Nr. of Optimal Run: {i}")
    new_candidates = gen_next_point(init_x, init_y, best_observed_y, bounds, 1)
    new_results = target_function(new_candidates, 0).unsqueeze(-1)
    print(f"The new candidate are: {new_candidates}")

    init_x = torch.cat([init_x, new_candidates])
    init_y = torch.cat([init_y, new_results])

    best_observed_y = init_y.max().item()
    print(f"The best observed value is: {best_observed_y}")
# Out:
# C:\Users\MajidMortazavi\AppData\Local\Temp\ipykernel_24912\987756712.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_y = torch.tensor(train_y)
# Nr. of Optimal Run: 0
# The next point to be evaluated is tensor([[-0.4075]])
# The new candidate are: tensor([[-0.4075]])
# The best observed value is: 0.49702654036345206
# Nr. of Optimal Run: 1
# The next point to be evaluated is tensor([[-0.3426]])
# The new candidate are: tensor([[-0.3426]])
# The best observed value is: 0.49896305799484253
# Nr. of Optimal Run: 2
# The next point to be evaluated is tensor([[-0.3623]])
# The new candidate are: tensor([[-0.3623]])
# The best observed value is: 0.5003179311752319
# Nr. of Optimal Run: 3
# The next point to be evaluated is tensor([[-0.3620]])
# The new candidate are: tensor([[-0.3620]])
# The best observed value is: 0.5003265142440796
# Nr. of Optimal Run: 4
# The next point to be evaluated is tensor([[-0.3615]])
# The new candidate are: tensor([[-0.3615]])
# The best observed value is: 0.500338077545166
# Nr. of Optimal Run: 5
# The next point to be evaluated is tensor([[-0.3612]])
# The new candidate are: tensor([[-0.3612]])
# The best observed value is: 0.5003437399864197
# Nr. of Optimal Run: 6
# The next point to be evaluated is tensor([[-0.3610]])
# The new candidate are: tensor([[-0.3610]])
# The best observed value is: 0.5003471374511719
# Nr. of Optimal Run: 7
# The next point to be evaluated is tensor([[-0.3608]])
# The new candidate are: tensor([[-0.3608]])
# The best observed value is: 0.5003494024276733
# Nr. of Optimal Run: 8
# The next point to be evaluated is tensor([[-0.3607]])
# The new candidate are: tensor([[-0.3607]])
# The best observed value is: 0.500351071357727
# Nr. of Optimal Run: 9
# The next point to be evaluated is tensor([[-0.3606]])
# The new candidate are: tensor([[-0.3606]])
# The best observed value is: 0.5003522634506226

# %% [markdown]
# ### Compute posterior over test points and plot fit

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# use a GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float

# %%
lower_bound = -2
upper_bound = 3
num_of_points = 10
noise = 0

train_X, train_Y, best_observed_y = generate_initial_data(lower_bound, upper_bound, num_of_points, noise)

model = SingleTaskGP(train_X, train_Y)
model.likelihood.noise_covar.register_constraint("raw_noise", GreaterThan(1e-5))
mll = ExactMarginalLogLikelihood(likelihood=model.likelihood, model=model)
fit_gpytorch_model(mll)

# set model (and likelihood)
model.eval()
# Out:
# C:\Users\MajidMortazavi\AppData\Local\Temp\ipykernel_24912\987756712.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_y = torch.tensor(train_y)
# SingleTaskGP(
#   (likelihood): GaussianLikelihood(
#     (noise_covar): HomoskedasticNoise(
#       (noise_prior): GammaPrior()
#       (raw_noise_constraint): GreaterThan(1.000E-05)
#     )
#   )
#   (mean_module): ConstantMean()
#   (covar_module): ScaleKernel(
#     (base_kernel): MaternKernel(
#       (lengthscale_prior): GammaPrior()
#       (raw_lengthscale_constraint): Positive()
#       (distance_module): Distance()
#     )
#     (outputscale_prior): GammaPrior()
#     (raw_outputscale_constraint): Positive()
#   )
# )

# %%
# Initialize plot
f, ax = plt.subplots(1, 1, figsize=(6, 4))
# test model on 101 regular spaced points on the interval [0, 1]
test_X = torch.linspace(lower_bound, upper_bound, 101, dtype=dtype, device=device)
# no need for gradients
with torch.no_grad():
    # compute posterior
    posterior = model.posterior(test_X)
    # Get upper and lower confidence bounds (2 standard deviations from the mean)
    lower, upper = posterior.mvn.confidence_region()
    # Plot training points as black stars
    ax.plot(train_X.cpu().numpy(), train_Y.cpu().numpy(), 'k*')
    # Plot posterior means as blue line
    ax.plot(test_X.cpu().numpy(), posterior.mean.cpu().numpy(), 'b')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(test_X.cpu().numpy(), lower.cpu().numpy(), upper.cpu().numpy(), alpha=0.5)
ax.legend(['Observed Data', 'Mean', 'Confidence'])
plt.tight_layout()
